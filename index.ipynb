# %% [markdown]
# <!--gitcreds::gitcreds_set()-->

# %% [raw]
# ---
# title: "Maurício Garcia de Camargo"
# lang: pt-br
# engine: knitr
#
# ---

# %% [markdown]
# ```{css,  echo=FALSE}
# .justify {
#  text-align:
# justify !important}
# ```
#
#
# :::: {.columns}
# ::: {.column width="20%"}
# ![](img/Eu4.jpg){width=80}
# :::
# ::: {.column width="80%"}
# <br>
# Professor da Universidade Federal de Rio Grande (FURG)
# :::
# ::::
#
# ----
#
# :::{.justify}
# Este é o meu site pessoal onde concentro todas as minhas atividades profissionais como professor e pesquisador do [Instituto de Oceanografia (IO)](http://www.io.furg.br) e do [Instituto de Matemática, Estatística e Física](http://www.imef.furg.br) da [Universidade Federal do Rio Grande - FURG](http://www.furg.br). Estou lotado no [Laboratório de Ecologia de Invertebrados Bentônicos](https://io.furg.br/pesquisa/laboratorios) do [IO](http://www.io.furg.br).
# :::
#
#
# <br>
# Todo o conteúdo do site é livre para uso [não comercial](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.pt_BR).
#
# ----
#
# ### Disciplinas atuais
# Ministro disciplinas de estatística ecológica, programação de computadores e diversidade de anelídeos poliquetas na graduação e na pós-graduação.
#
# <!-- e metodologia da ciência na graduação. -->
#
# **Disciplinas do segundo semestre de 2025:**
#
# - Lógica da programação e análise de dados em R (Iniciando - aguardem conteúdo)
#
# -  Delineamentos experimentais em ecologia (Início em 21/10/25)
#
# **Disciplinas do primeiro semestre de 2025:**
#
# - Biodiversidade de invertebrados marinhos - Anelídeos poliquetas (Encerrada)<!--(https://mauricio-camargo.github.io/Biodiversidade2025/)-->
#
# <!--
# -----
# ### Orientações em pesquisa
# Oriento alunos de graduação e de pós-graduação em ecologia de comunidades bentônicas com interesse em estatística ambiental e linguagens de programação.
# -->
#
# <!--
# -----
# ### Atividades administrativas
# Atualmente sou coordenador substituto do curso de Oceanologia.
# -->
#
# ------
#
# ### Contato
#
# - E-mail: [camargofurg@gmail.com](mailto:camargofurg@gmail.com)
# - [Currículo Lattes](http://lattes.cnpq.br/6674393714532464)
# - Github: <http://www.github.com/mauricio-camargo>
# <!-- - Facebook: https://www.facebook.com/profile.php?id=100014050901446 -->
# - Endereço: Laboratório de Invertebrados Bentônicos - Instituto de Oceanografia. Av. Itália, km 8. Campus Carreiros. Rio Grande - RS. CEP 96203-900.
#
# <center>
#   <hr width="100%" size="3px">
#   <p> <a href="http://www.furg.br"><img src="img/furg1.jpg"> </a>
#   <a href="http://www.io.furg.br"><img src="img/io1.png"> </a>
#   <a href="http://www.imef.furg.br"><img src="img/imef1.jpg"> </a>
#
# <p>
# <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/deed.pt_BR">
# <img src="img/CC_by-nc-sa_88x31.png" alt="Licença Creative Commons 4.0"> </a>
# </p>
# <p>
# <font size="2"> Conteúdo disponível através da Licença Creative Commons 4.0 <br>
# Maurício Garcia de Camargo<br>
# <!--Número de hits desde 19 de Junho de 2023-->
# <br>
# </font>
#
# <!--
# <a href="http://www.webcontadores.com" title="contador de visitas para blog"><img src="http://counter7.01counter.com/private/webcontadores.php?c=aae54ceffc577de6f41508e54a80e1e7" border="0" title="contador de visitas" alt="contador de visitas"></a>
# -->
#
# <!--
# <div id="sfcq1fsm943kycc6ceunewfnxcdjlcz1m3w"></div>
# <script type="text/javascript" src="https://counter2.optistats.ovh/private/counter.js?c=q1fsm943kycc6ceunewfnxcdjlcz1m3w&down=async" async></script>
# <br><a href="https://www.webcontadores.com">contador de visitas para webnode</a><noscript><a href="https://www.webcontadores.com" title="contador de visitas para webnode"><img src="https://counter2.optistats.ovh/private/webcontadores.php?c=q1fsm943kycc6ceunewfnxcdjlcz1m3w" border="0" title="contador de visitas para webnode" alt="contador de visitas para webnode"></a></noscript>
# -->
#
# <div id="sfcy9ntznsj4amxzj5j792l3wz9ladul5hx"></div>
# <script type="text/javascript" src="https://counter2.optistats.ovh/private/counter.js?c=y9ntznsj4amxzj5j792l3wz9ladul5hx&down=async" async></script>
# <br>
#
# </center>
